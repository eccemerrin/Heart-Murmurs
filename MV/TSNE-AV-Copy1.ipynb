# %% [markdown]
# ### features:
# * spectogram coef
# * zero crossing rate
# * selected chromogram values
# * selected tempogram values
# * wavelet levels

# %%
import pandas as pd 
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import auc
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, recall_score
import matplotlib.pyplot as plt
import itertools
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
path = "/Users/ecem/Desktop/phonocardiogram/data/AV"

# %% [markdown]
# ## Load data

# %% [markdown]
# Here, our target is to predict disease of patients with multiple diseases. So; our y will be disease column of two column indicatin geach patients disease.

# %%
present_df = pd.read_csv(path + "/present/present_AV_p_features.csv", index_col = 0) #1245, 18752
present_df
# Out:
#             freq_0        freq_1        freq_2        freq_3        freq_4  \
# 0     4.053941e-11  5.722774e-11  5.674817e-11  5.604892e-11  5.585778e-11
# 1     7.029058e-11  1.004992e-10  1.032565e-10  1.067600e-10  1.103392e-10
# 2     6.242156e-11  8.838291e-11  8.841429e-11  8.813666e-11  8.771334e-11
# 3     5.658126e-11  8.147643e-11  8.364837e-11  8.546564e-11  8.658269e-11
# 4     6.675927e-11  9.572394e-11  9.878655e-11  1.025290e-10  1.061944e-10
# ...            ...           ...           ...           ...           ...
# 1240  1.421592e-10  2.041520e-10  2.113140e-10  2.194710e-10  2.268139e-10
# 1241  1.923120e-10  2.702142e-10  2.654474e-10  2.609435e-10  2.570200e-10
# 1242  2.886341e-10  4.070661e-10  4.033971e-10  3.969121e-10  3.879849e-10
# 1243  2.906344e-10  4.077050e-10  3.979113e-10  3.821000e-10  3.611274e-10
# 1244  2.403442e-10  3.484523e-10  3.694375e-10  3.969165e-10  4.344074e-10
#
# ...

# %%
absent_df = pd.read_csv(path + "/absent/absent_AV_p_features.csv", index_col = 0) #6890, 18752
absent_df
# Out:
#             freq_0        freq_1        freq_2        freq_3        freq_4  \
# 0     9.032866e-11  1.283307e-10  1.273762e-10  1.246309e-10  1.201637e-10
# 1     8.539332e-11  1.200104e-10  1.177622e-10  1.140818e-10  1.091471e-10
# 2     6.311897e-11  8.902436e-11  8.830606e-11  8.712377e-11  8.552773e-11
# 3     6.343676e-11  9.022266e-11  9.124019e-11  9.224844e-11  9.295056e-11
# 4     7.630806e-11  1.079990e-10  1.080264e-10  1.076320e-10  1.065868e-10
# ...            ...           ...           ...           ...           ...
# 6975  4.391115e-11  6.325533e-11  6.596380e-11  6.906291e-11  7.179823e-11
# 6976  6.021307e-11  8.525027e-11  8.540722e-11  8.544461e-11  8.529221e-11
# 6977  4.200291e-11  5.951789e-11  5.957082e-11  5.933758e-11  5.883054e-11
# 6978  3.381760e-11  4.864368e-11  4.980425e-11  5.108621e-11  5.242817e-11
# 6979  5.095358e-11  7.242467e-11  7.302264e-11  7.362782e-11  7.416672e-11
#
# ...

# %%
labels = np.concatenate((np.ones((1245)), np.zeros((6980))), axis = 0)
labels.shape
# Out:
# (8225,)

# %%
df = pd.concat([present_df, absent_df])

# %%
color = np.ones((1245))

# %% [markdown]
# ## spectogram

# %%
from sklearn.manifold import TSNE
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', perplexity = 10).fit_transform(present_df.iloc[:, :16384])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = color)
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', 
              perplexity = 10).fit_transform(absent_df.iloc[:, :16384])
plt.scatter(X_tsne[:,0], X_tsne[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', 
              perplexity = 30).fit_transform(df.iloc[:, :16384])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = labels)
plt.show()

# %% [markdown]
# ## wavelet

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(present_df.iloc[:, 16384:18699])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = color)
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', 
              perplexity = 10).fit_transform(absent_df.iloc[:, 16384:18699])
plt.scatter(X_tsne[:,0], X_tsne[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', 
              perplexity = 10).fit_transform(df.iloc[:, 16384:18699])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c =labels)
plt.show()

# %% [markdown]
# ## zcrs

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(present_df.iloc[:, 18699:18704])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = color)
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(absent_df.iloc[:, 18699:18704])
plt.scatter(X_tsne[:,0], X_tsne[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(df.iloc[:, 18699:18704])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c=labels)
plt.show()

# %% [markdown]
# ## chromogram

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(present_df.iloc[:, 18704:18710])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = color)
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(absent_df.iloc[:, 18704:18710])
plt.scatter(X_tsne[:,0], X_tsne[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(df.iloc[:, 18704:18710])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c=labels)
plt.show()

# %% [markdown]
# ## tempogram

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(present_df.iloc[:, 18710:])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = color)
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(absent_df.iloc[:, 18710:])
plt.scatter(X_tsne[:,0], X_tsne[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random',
              perplexity = 10).fit_transform(df.iloc[:, 18710:])
plt.scatter(X_tsne[:,0], X_tsne[:,1], c=labels)
plt.show()

# %% [markdown]
# ## total

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', perplexity = 10).fit_transform(present_df)
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = color)
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', perplexity = 10).fit_transform(absent_df)
plt.scatter(X_tsne[:,0], X_tsne[:,1])
plt.show()

# %%
fig = plt.figure(figsize=(8,6));
X_tsne = TSNE(n_components=2, learning_rate='auto',init='random', perplexity = 30).fit_transform(df)
plt.scatter(X_tsne[:,0], X_tsne[:,1], c = labels)
plt.show()
