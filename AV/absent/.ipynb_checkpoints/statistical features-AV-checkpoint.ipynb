# %% [markdown]
# In this notebook we are going to focus on features which will be derived from time domain characteristics.

# %%
import numpy as np
import math
from scipy.signal import argrelextrema, find_peaks

# %%
path = "/Users/ecem/Desktop/phonocardiogram/data/AV/absent"

# %%
waves = np.load(path + "/absent_AV_waves_10sec.npy", allow_pickle= True)

# %%
waves.shape
# Out:
# (6980, 40000)

# %% [markdown]
# ## Mean:

# %%
mean_ = np.zeros(waves.shape[0])

# %%
for i in range(waves.shape[0]):
    mean_[i] = waves[i].mean()

# %% [markdown]
# ## Standart deviation:

# %%
std_ = np.zeros(waves.shape[0])
for i in range(waves.shape[0]):
    std_[i] = waves[i].std()

# %% [markdown]
# ## Skewness

# %%
from scipy.stats import skew

# %%
skew_ = np.zeros(waves.shape[0])
for i in range(waves.shape[0]):
    skew_[i] = skew(waves[i])

# %% [markdown]
# ## Kurtosis

# %%
import scipy.stats

# %%
kurt_ = np.zeros(waves.shape[0])
for i in range(waves.shape[0]):
    kurt_[i] =  scipy.stats.kurtosis(waves[i])

# %% [markdown]
# ## Harmonic Mean

# %%
harmonic_ = np.zeros(waves.shape[0])
for i in range(waves.shape[0]):
    harmonic_[i] =  scipy.stats.hmean(waves[i]* waves[i])

# %% [markdown]
# ## Autocorrelation

# %%
from scipy import signal
from scipy.signal import find_peaks

# %%
autocorr = signal.fftconvolve(waves[0], waves[0], mode='full')

# %%
import matplotlib.pyplot as plt
>>> fig, (ax_orig, ax_mag) = plt.subplots(2, 1)
>>> ax_orig.plot(waves[0])
>>> ax_orig.set_title('White noise')
>>> ax_mag.plot(np.arange(-len(waves[0])+1,len(waves[0])), autocorr)
>>> ax_mag.set_title('Autocorrelation')
>>> fig.tight_layout()
>>> fig.show()
# Out:
# /var/folders/gd/3d6ckpdn4q30skhxnvs_p7b80000gn/T/ipykernel_2227/835141848.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
peaks = find_peaks(autocorr, height = 10)

# %%
>>> plt.plot(autocorr)
>>> plt.plot(peaks[0], autocorr[peaks[0]], "x")
>>> plt.plot(np.zeros_like(autocorr), "--", color="gray")
>>> plt.show()

# %%
autocorr = signal.fftconvolve(waves[79], waves[79], mode='full')

# %%
>>> fig, (ax_orig, ax_mag) = plt.subplots(2, 1)
>>> ax_orig.plot(waves[79])
>>> ax_orig.set_title('White noise')
>>> ax_mag.plot(np.arange(-len(waves[79])+1,len(waves[79])), autocorr)
>>> ax_mag.set_title('Autocorrelation')
>>> fig.tight_layout()
>>> fig.show()

peaks = find_peaks(autocorr, height = 10)
# Out:
# /var/folders/gd/3d6ckpdn4q30skhxnvs_p7b80000gn/T/ipykernel_2227/759871826.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
>>> plt.plot(autocorr)
>>> plt.plot(peaks[0], autocorr[peaks[0]], "x")
>>> plt.plot(np.zeros_like(autocorr), "--", color="gray")
>>> plt.show()

# %%
peaks[0].mean()
# Out:
# 26078.9341563786

# %%
auto_corr = np.zeros((waves.shape[0], 79999))
peaks_ = []
for i in range(waves.shape[0]):
    auto_corr[i,:] = signal.fftconvolve(waves[i], waves[i], mode='full')
    peaks_.append(find_peaks(auto_corr[i], height = 0)[1]["peak_heights"].mean())

# %%
peaks_ = np.array(peaks_)
peaks_.shape
# Out:
# (6980,)

# %% [markdown]
# # Now lets create their dataframes

# %%
import pandas as pd

# %%
mean_df = pd.DataFrame(mean_, columns =["mean"])
mean_df.head()
# Out:
#        mean
# 0  0.000601
# 1  0.000729
# 2  0.000424
# 3  0.000763
# 4  0.000339

# %%
std_df = pd.DataFrame(std_, columns =["std"])
std_df.head()
# Out:
#         std
# 0  0.047468
# 1  0.043495
# 2  0.032711
# 3  0.035711
# 4  0.026210

# %%
kurtosis_df = pd.DataFrame(kurt_, columns = ["kurtosis"])
kurtosis_df.head()
# Out:
#     kurtosis
# 0   4.008844
# 1  11.998997
# 2   8.158025
# 3   4.388212
# 4   7.420183

# %%
skew_df = pd.DataFrame(skew_, columns =["skewness"])
skew_df.head()
# Out:
#    skewness
# 0 -0.070311
# 1 -0.142421
# 2 -0.184550
# 3 -0.217664
# 4 -0.510709

# %%
harmonic_df = pd.DataFrame(harmonic_, columns =["harmonic mean"])
harmonic_df.head()
# Out:
#    harmonic mean
# 0   9.133927e-09
# 1   3.546310e-10
# 2   3.581994e-10
# 3   3.277813e-09
# 4   1.183629e-09

# %%
autocorr_peaks_df = pd.DataFrame(peaks_, columns =["ac peak height mean"])
autocorr_peaks_df.head()
# Out:
#    ac peak height mean
# 0             1.760248
# 1             0.986747
# 2             0.709413
# 3             1.056693
# 4             0.517541

# %% [markdown]
# ## Now concatenate all features

# %%
df = pd.concat([mean_df, std_df, skew_df, kurtosis_df, harmonic_df, autocorr_peaks_df], axis =1)

# %%
df
# Out:
#           mean       std  skewness    kurtosis  harmonic mean  \
# 0     0.000601  0.047468 -0.070311    4.008844   9.133927e-09
# 1     0.000729  0.043495 -0.142421   11.998997   3.546310e-10
# 2     0.000424  0.032711 -0.184550    8.158025   3.581994e-10
# 3     0.000763  0.035711 -0.217664    4.388212   3.277813e-09
# 4     0.000339  0.026210 -0.510709    7.420183   1.183629e-09
# ...        ...       ...       ...         ...            ...
# 6975  0.000993  0.024940 -2.930285   51.780026   4.174179e-11
# 6976  0.002337  0.016788 -0.146274   92.880627   4.800422e-10
# 6977  0.002311  0.014002 -0.752299    8.048801   6.033321e-09
# 6978  0.001595  0.015721 -0.679164    9.336197   9.215009e-09
# 6979  0.000496  0.048094  1.486420  104.207566   3.039523e-09
#
#       ac peak height mean
# 0                1.760248
# 1                0.986747
# 2                0.709413
# 3                1.056693
# 4                0.517541
# ...                   ...
# 6975             0.326455
# 6976             0.221183
# 6977             0.268456
# 6978             0.192344
# 6979             0.985759
#
# [6980 rows x 6 columns]

# %%
df.to_csv("/Users/ecem/Desktop/phonocardiogram/data/AV/absent/AV-statistical-features.csv" )
