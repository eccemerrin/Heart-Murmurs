# %% [markdown]
# ### features:

# %%
import pandas as pd 
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import auc
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, recall_score
import matplotlib.pyplot as plt
import itertools

# %%
path = "/Users/ecem/Desktop/phonocardiogram/data/binary/MV"

# %% [markdown]
# ## absent

# %%
absent_time_domain = pd.read_csv(path + "/absent_time_domain.csv", index_col = 0)
absent_statistical = pd.read_csv(path + "/absent_statistical.csv", index_col = 0)
absent_fractal = pd.read_csv(path + "/absent_mock_features.csv", index_col = 0)
absent_bandpower = pd.read_csv(path + "/absent_bandpower_and_peaks.csv", index_col = 0)
absent_shan_ent = pd.read_csv(path + "/absent_shannon.csv", index_col = 0)
absent_norm_peak = pd.read_csv(path + "/absent_normalized_peaks.csv", index_col = 0)

# %%
absent_features = pd.concat([absent_statistical, 
                             absent_time_domain, 
                             absent_fractal, 
                             absent_bandpower, 
                             absent_shan_ent, absent_norm_peak], axis = 1)
absent_features
# Out:
#           mean       std  skewness    kurtosis  harmonic mean  \
# 0     0.000284  0.072942  0.054146   31.069661   5.006604e-09
# 1     0.000351  0.049968  1.094875   24.315545   6.063007e-09
# 2     0.000436  0.051864  0.029475   29.158186   2.090658e-08
# 3     0.000727  0.044003  1.731632   28.593493   4.958314e-09
# 4     0.000233  0.100517 -0.345864   26.796967   9.207950e-11
# ...        ...       ...       ...         ...            ...
# 5529  0.000387  0.024044 -0.822139   36.978596   3.349154e-10
# 5530  0.000682  0.021494 -0.873249   36.888931   7.669467e-10
# 5531  0.000346  0.024837  0.249935   30.752685   1.271457e-08
# 5532  0.000686  0.022753  0.894157   30.273003   1.056468e-08
# 5533  0.000031  0.061020  0.485993  122.403923   0.000000e+00
#
#       ac peak height mean    energy   entropy  spectral entropy  \
# 0                2.832597  0.005321  2.876008          0.228218
# 1                1.229969  0.002497  2.935257          0.087870
# 2                1.328972  0.002690  2.651129          0.321711
# 3                0.892528  0.001937  2.723452          0.090231
# 4                5.343688  0.010104  2.268402          0.404034
# ...                   ...       ...       ...               ...
# 5529             0.318791  0.000578  2.831500          0.333597
# 5530             0.292918  0.000462  2.841987          0.185934
# 5531             0.429625  0.000617  2.932797          0.122697
# 5532             0.324708  0.000518  2.922031          0.380315
# 5533             1.318381  0.003723  1.476799          0.059921
#
#       spectral rolloff  ...  26'th bandpower  27'th bandpower  \
# 0              0.08395  ...     8.524920e-14     1.885548e-14
# 1              0.04450  ...     2.977098e-14     7.057573e-15
# 2              0.07980  ...     3.622619e-14     8.076045e-15
# 3              0.02625  ...     3.184328e-14     7.559674e-15
# 4              0.09510  ...     1.374978e-13     2.868335e-14
# ...                ...  ...              ...              ...
# 5529           0.05255  ...     1.071197e-14     2.422433e-15
# 5530           0.04705  ...     4.998688e-15     1.151392e-15
# 5531           0.03990  ...     8.513479e-15     2.004946e-15
# 5532           0.05030  ...     9.991091e-15     2.293756e-15
# 5533           0.05800  ...     4.020642e-14     9.508840e-15
#
#       28'th bandpower    approx      lvl5      lvl4      lvl3      lvl2  \
# 0        2.476988e-15  7.129603  7.132032  7.826765  8.515772  9.208351
# 1        8.711475e-16  7.134497  7.134784  7.824697  8.515053  9.207725
# 2        1.127257e-15  7.134604  7.136040  7.827669  8.518528  9.210703
# 3        9.215427e-16  7.132331  7.126694  7.827230  8.512377  9.205573
# 4        4.059442e-15  7.130419  7.132550  7.824321  8.514433  9.207611
# ...               ...       ...       ...       ...       ...       ...
# 5529     2.995373e-16  7.136390  7.138465  7.798155  8.500382  9.202866
# 5530     1.472087e-16  7.135462  7.138962  7.819972  8.500667  9.208067
# 5531     2.503379e-16  7.138690  7.136700  7.821034  8.508180  9.198367
# 5532     2.851242e-16  7.132191  7.135703  7.813076  8.499325  9.178487
# 5533     1.190233e-15  7.138405  7.138266  7.828197  8.518756  9.210375
#
#           lvl1  ac num of peaks
# 0     9.903504             24.0
# 1     9.903694             19.0
# 2     9.903722             34.0
# 3     9.903753              5.0
# 4     9.903617             58.0
# ...        ...              ...
# 5529  9.903716            142.0
# 5530  9.903703            113.0
# 5531  9.903690             29.0
# 5532  9.903737             47.0
# 5533  9.903690              2.0
#
# [5534 rows x 36 columns]

# %% [markdown]
# ## present

# %%
present_time_domain = pd.read_csv(path + "/present_time_domain.csv", index_col = 0)
present_statistical = pd.read_csv(path + "/present_statistical.csv", index_col = 0)
present_fractal = pd.read_csv(path + "/present_mock_features.csv", index_col = 0)
present_bandpower = pd.read_csv(path + "/present_bandpower_and_peak.csv", index_col = 0)
present_shan_ent = pd.read_csv(path + "/present_shannon.csv", index_col = 0)
present_norm_peak = pd.read_csv(path + "/present_normalized_peaks.csv", index_col = 0)

# %%
present_features = pd.concat([present_statistical, 
                             present_time_domain, 
                             present_fractal, 
                             present_bandpower, 
                             present_shan_ent, present_norm_peak], axis = 1)
present_features
# Out:
#           mean       std  skewness    kurtosis  harmonic mean  \
# 0    -0.001512  0.059670  0.751900   92.901332   1.627555e-10
# 1    -0.000412  0.019801 -0.659232   15.586249   3.339466e-11
# 2     0.000172  0.011843  0.248045   29.625304   4.229319e-10
# 3     0.000048  0.029366  4.424341  385.096582   7.171397e-11
# 4     0.000685  0.015039 -1.157463   14.906036   1.454162e-09
# ...        ...       ...       ...         ...            ...
# 1075 -0.000493  0.084828 -0.227853    3.791500   4.501717e-10
# 1076 -0.000356  0.082798 -0.004227    3.171172   2.295126e-09
# 1077 -0.000629  0.082643 -0.107542    3.280987   1.091081e-10
# 1078  0.000074  0.082421 -0.107801    3.698629   4.424084e-08
# 1079 -0.000294  0.101420  0.403583   14.930259   0.000000e+00
#
#       ac peak height mean    energy   entropy  spectral entropy  \
# 0                1.072669  0.003563  0.712973          0.154444
# 1                0.277197  0.000392  3.078976          0.177611
# 2                0.109943  0.000140  2.962774          0.063993
# 3                0.353585  0.000862  1.297542          0.207682
# 4                0.157553  0.000227  2.669629          0.302242
# ...                   ...       ...       ...               ...
# 1075            12.322025  0.007196  3.057676          0.021017
# 1076            10.250002  0.006856  3.100402          0.016613
# 1077             9.873036  0.006830  3.160949          0.029256
# 1078            10.836644  0.006793  3.087762          0.020008
# 1079            13.525428  0.010286  2.732414          0.139074
#
#       spectral rolloff  ...  26'th bandpower  27'th bandpower  \
# 0              0.05685  ...     4.909269e-14     1.148709e-14
# 1              0.07225  ...     7.311267e-15     1.686230e-15
# 2              0.03820  ...     2.450151e-15     5.753644e-16
# 3              0.06910  ...     5.880340e-15     1.348516e-15
# 4              0.08500  ...     4.272949e-15     9.378780e-16
# ...                ...  ...              ...              ...
# 1075           0.01615  ...     8.205695e-14     1.971666e-14
# 1076           0.01610  ...     1.110520e-13     2.674298e-14
# 1077           0.01745  ...     9.242863e-14     2.222887e-14
# 1078           0.01665  ...     7.195662e-14     1.727794e-14
# 1079           0.04185  ...     1.735855e-13     4.037539e-14
#
#       28'th bandpower    approx      lvl5      lvl4      lvl3      lvl2  \
# 0        1.453500e-15  5.800856  5.837626  6.300541  7.423002  7.878796
# 1        2.192429e-16  6.614944  6.513192  7.122138  7.841738  8.530138
# 2        7.046963e-17  6.513485  6.683204  7.325324  8.122154  8.819523
# 3        1.782360e-16  6.507287  5.982985  6.039231  7.517050  8.357476
# 4        1.163177e-16  6.668745  6.455091  6.927773  7.670650  8.355482
# ...               ...       ...       ...       ...       ...       ...
# 1075     2.437808e-15  6.642757  6.601917  7.409121  8.112822  8.779662
# 1076     3.269505e-15  6.647131  6.597483  7.375110  8.150270  8.782596
# 1077     2.736582e-15  6.650374  6.556908  7.285572  7.990579  8.689161
# 1078     2.139523e-15  6.613884  6.551631  7.263662  7.981016  8.699569
# 1079     5.103111e-15  6.614380  6.286993  6.779430  7.285044  7.937519
#
#           lvl1  ac num of peaks
# 0     6.731358              3.0
# 1     6.721701              9.0
# 2     7.828227             31.0
# 3     8.786798              5.0
# 4     8.933067            150.0
# ...        ...              ...
# 1075  9.165568             59.0
# 1076  8.082554             73.0
# 1077  8.301695             63.0
# 1078  9.198726            102.0
# 1079  8.566767             36.0
#
# [1080 rows x 36 columns]

# %% [markdown]
# ## concat features

# %%
df = pd.concat([present_features, absent_features], axis = 0) 
df
# Out:
#           mean       std  skewness    kurtosis  harmonic mean  \
# 0    -0.001512  0.059670  0.751900   92.901332   1.627555e-10
# 1    -0.000412  0.019801 -0.659232   15.586249   3.339466e-11
# 2     0.000172  0.011843  0.248045   29.625304   4.229319e-10
# 3     0.000048  0.029366  4.424341  385.096582   7.171397e-11
# 4     0.000685  0.015039 -1.157463   14.906036   1.454162e-09
# ...        ...       ...       ...         ...            ...
# 5529  0.000387  0.024044 -0.822139   36.978596   3.349154e-10
# 5530  0.000682  0.021494 -0.873249   36.888931   7.669467e-10
# 5531  0.000346  0.024837  0.249935   30.752685   1.271457e-08
# 5532  0.000686  0.022753  0.894157   30.273003   1.056468e-08
# 5533  0.000031  0.061020  0.485993  122.403923   0.000000e+00
#
#       ac peak height mean    energy   entropy  spectral entropy  \
# 0                1.072669  0.003563  0.712973          0.154444
# 1                0.277197  0.000392  3.078976          0.177611
# 2                0.109943  0.000140  2.962774          0.063993
# 3                0.353585  0.000862  1.297542          0.207682
# 4                0.157553  0.000227  2.669629          0.302242
# ...                   ...       ...       ...               ...
# 5529             0.318791  0.000578  2.831500          0.333597
# 5530             0.292918  0.000462  2.841987          0.185934
# 5531             0.429625  0.000617  2.932797          0.122697
# 5532             0.324708  0.000518  2.922031          0.380315
# 5533             1.318381  0.003723  1.476799          0.059921
#
#       spectral rolloff  ...  26'th bandpower  27'th bandpower  \
# 0              0.05685  ...     4.909269e-14     1.148709e-14
# 1              0.07225  ...     7.311267e-15     1.686230e-15
# 2              0.03820  ...     2.450151e-15     5.753644e-16
# 3              0.06910  ...     5.880340e-15     1.348516e-15
# 4              0.08500  ...     4.272949e-15     9.378780e-16
# ...                ...  ...              ...              ...
# 5529           0.05255  ...     1.071197e-14     2.422433e-15
# 5530           0.04705  ...     4.998688e-15     1.151392e-15
# 5531           0.03990  ...     8.513479e-15     2.004946e-15
# 5532           0.05030  ...     9.991091e-15     2.293756e-15
# 5533           0.05800  ...     4.020642e-14     9.508840e-15
#
#       28'th bandpower    approx      lvl5      lvl4      lvl3      lvl2  \
# 0        1.453500e-15  5.800856  5.837626  6.300541  7.423002  7.878796
# 1        2.192429e-16  6.614944  6.513192  7.122138  7.841738  8.530138
# 2        7.046963e-17  6.513485  6.683204  7.325324  8.122154  8.819523
# 3        1.782360e-16  6.507287  5.982985  6.039231  7.517050  8.357476
# 4        1.163177e-16  6.668745  6.455091  6.927773  7.670650  8.355482
# ...               ...       ...       ...       ...       ...       ...
# 5529     2.995373e-16  7.136390  7.138465  7.798155  8.500382  9.202866
# 5530     1.472087e-16  7.135462  7.138962  7.819972  8.500667  9.208067
# 5531     2.503379e-16  7.138690  7.136700  7.821034  8.508180  9.198367
# 5532     2.851242e-16  7.132191  7.135703  7.813076  8.499325  9.178487
# 5533     1.190233e-15  7.138405  7.138266  7.828197  8.518756  9.210375
#
#           lvl1  ac num of peaks
# 0     6.731358              3.0
# 1     6.721701              9.0
# 2     7.828227             31.0
# 3     8.786798              5.0
# 4     8.933067            150.0
# ...        ...              ...
# 5529  9.903716            142.0
# 5530  9.903703            113.0
# 5531  9.903690             29.0
# 5532  9.903737             47.0
# 5533  9.903690              2.0
#
# [6614 rows x 36 columns]

# %% [markdown]
# ## labels

# %%
y = np.concatenate((np.ones(1080), np.zeros(5534)), axis =0)
y.shape
# Out:
# (6614,)

# %% [markdown]
# ## Without threshold

# %%
X_train_, X_valid_, y_train_, y_valid_ = train_test_split(df, y, train_size=0.8, test_size=0.2,
                                                                random_state=42)

# %%
import xgboost as xgb

clf = xgb.XGBClassifier(objective= "binary:logistic", eval_metric = "logloss")

# %%
clf.fit(X_train_, y_train_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=6,
#               max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
yhat = clf.predict(X_valid_)

# %%
yhat.shape
# Out:
# (1323,)

# %%
y_valid_.shape
# Out:
# (1323,)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_valid_, yhat)
print("accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# accuracy: 100.00%

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_valid_, yhat, average= 'weighted')
print("recall: %.2f%%" % (recall * 100.0))
# Out:
# recall: 100.00%

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_valid_, yhat, average= 'weighted')
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# precision: 100.00%

# %%
from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_valid_, yhat)
print(f"ROC AUC: {score:.4f}")
# Out:
# ROC AUC: 1.0000

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf, X_valid_, y_valid_)
# Out:
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
names =["absent", "present"]
print(classification_report(y_valid_, yhat, target_names = names))
# Out:
#               precision    recall  f1-score   support
#
#       absent       1.00      1.00      1.00      1096
#      present       1.00      1.00      1.00       227
#
#     accuracy                           1.00      1323
#    macro avg       1.00      1.00      1.00      1323
# weighted avg       1.00      1.00      1.00      1323

# %%
precision, recall, thresholds = precision_recall_curve(y_valid_, yhat)
auc_score = auc(recall, precision)
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
plt.plot(recall, precision, marker='.')
plt.show()
print('AUC: %.3f' % auc_score)
# Out:
# AUC: 1.000

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_predictions(
    y_valid_,
    yhat,
    color="darkorange",
)
plt.plot([0, 1], [0, 1], "k--", label="random guess (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("One-vs-Rest ROC curves")
plt.legend()

# %% [markdown]
# ## With threshold

# %%
from sklearn.feature_selection import VarianceThreshold
vt = VarianceThreshold(threshold =  0.0001)   # düşük  threshold
_ = vt.fit(df)
masked = vt.get_support()
features_masked = df.loc[:, masked]

# %%
features_masked
# Out:
#            std  skewness    kurtosis  ac peak height mean   entropy  \
# 0     0.059670  0.751900   92.901332             1.072669  0.712973
# 1     0.019801 -0.659232   15.586249             0.277197  3.078976
# 2     0.011843  0.248045   29.625304             0.109943  2.962774
# 3     0.029366  4.424341  385.096582             0.353585  1.297542
# 4     0.015039 -1.157463   14.906036             0.157553  2.669629
# ...        ...       ...         ...                  ...       ...
# 5529  0.024044 -0.822139   36.978596             0.318791  2.831500
# 5530  0.021494 -0.873249   36.888931             0.292918  2.841987
# 5531  0.024837  0.249935   30.752685             0.429625  2.932797
# 5532  0.022753  0.894157   30.273003             0.324708  2.922031
# 5533  0.061020  0.485993  122.403923             1.318381  1.476799
#
#       spectral entropy  spectral rolloff  spectral centorid  katz f.a.  \
# 0             0.154444           0.05685           0.045449   1.664540
# 1             0.177611           0.07225           0.051270   2.121635
# 2             0.063993           0.03820           0.048226   1.943695
# 3             0.207682           0.06910           0.062547   1.568108
# 4             0.302242           0.08500           0.059660   2.185295
# ...                ...               ...                ...        ...
# 5529          0.333597           0.05255           0.053829   2.087690
# 5530          0.185934           0.04705           0.049657   2.009535
# 5531          0.122697           0.03990           0.040833   1.964303
# 5532          0.380315           0.05030           0.049928   2.132991
# 5533          0.059921           0.05800           0.044773   1.707946
#
#       higuchi f.a.  deterended fluctuations f.a.  peak max    approx  \
# 0         1.096912                      0.963840  0.055868  5.800856
# 1         1.097665                      0.917476  0.034192  6.614944
# 2         1.085673                      1.045490  0.027290  6.513485
# 3         1.090975                      0.748099  0.124638  6.507287
# 4         1.109614                      0.919040  0.021207  6.668745
# ...            ...                           ...       ...       ...
# 5529      1.212769                      0.942089  0.026750  7.136390
# 5530      1.153969                      0.983388  0.029469  7.135462
# 5531      1.130309                      1.010259  0.027500  7.138690
# 5532      1.192554                      0.968891  0.029858  7.132191
# 5533      1.141519                      0.803674  0.071307  7.138405
#
#           lvl5      lvl4      lvl3      lvl2      lvl1  ac num of peaks
# 0     5.837626  6.300541  7.423002  7.878796  6.731358              3.0
# 1     6.513192  7.122138  7.841738  8.530138  6.721701              9.0
# 2     6.683204  7.325324  8.122154  8.819523  7.828227             31.0
# 3     5.982985  6.039231  7.517050  8.357476  8.786798              5.0
# 4     6.455091  6.927773  7.670650  8.355482  8.933067            150.0
# ...        ...       ...       ...       ...       ...              ...
# 5529  7.138465  7.798155  8.500382  9.202866  9.903716            142.0
# 5530  7.138962  7.819972  8.500667  9.208067  9.903703            113.0
# 5531  7.136700  7.821034  8.508180  9.198367  9.903690             29.0
# 5532  7.135703  7.813076  8.499325  9.178487  9.903737             47.0
# 5533  7.138266  7.828197  8.518756  9.210375  9.903690              2.0
#
# [6614 rows x 19 columns]

# %%
X_train_, X_valid_, y_train_, y_valid_ = train_test_split(features_masked, y , train_size=0.8, test_size=0.2,
                                                                random_state=42)

# %%
clf = xgb.XGBClassifier(objective= "binary:logistic", eval_metric = "logloss")

# %%
clf.fit(X_train_, y_train_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=6,
#               max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
yhat = clf.predict(X_valid_)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_valid_, yhat)
print("accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# accuracy: 100.00%

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_valid_, yhat, average= 'weighted')
print("recall: %.2f%%" % (recall * 100.0))
# Out:
# recall: 100.00%

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_valid_, yhat, average= 'weighted')
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# precision: 100.00%

# %%
names =["absent", "present"]
print(classification_report(y_valid_, yhat, target_names = names))
# Out:
#               precision    recall  f1-score   support
#
#       absent       1.00      1.00      1.00      1096
#      present       1.00      1.00      1.00       227
#
#     accuracy                           1.00      1323
#    macro avg       1.00      1.00      1.00      1323
# weighted avg       1.00      1.00      1.00      1323
