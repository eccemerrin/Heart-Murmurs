# %%
import pandas as pd 
from scipy.stats import mannwhitneyu
from scipy import stats
import numpy as np

# %%
AV_path =  "/Users/ecem/Desktop/phonocardiogram/data/AV/present"
MV_path =  "/Users/ecem/Desktop/phonocardiogram/data/MV/present"
PV_path =  "/Users/ecem/Desktop/phonocardiogram/data/PV/present"
TV_path =  "/Users/ecem/Desktop/phonocardiogram/data/TV/present"

# %% [markdown]
# # Time domain features

# %%
av = np.load(AV_path + "/rqa_AV.npy", allow_pickle = True)
mv = np.load(MV_path + "/rqa_MV.npy", allow_pickle = True)
pv = np.load(PV_path + "/rqa_PV.npy", allow_pickle = True)
tv = np.load(TV_path + "/rqa_TV.npy", allow_pickle = True)

# %%
av
# Out:
# array([[2.        , 2.        , 2.        , ..., 2.84661316, 1.00736522,
#         0.99999988],
#        [2.        , 2.        , 2.        , ..., 0.        , 1.00000004,
#         0.99999996],
#        [2.        , 2.        , 2.        , ..., 0.        , 1.00000004,
#         0.99999996],
#        ...,
#        [2.        , 2.        , 2.        , ..., 4.60704989, 1.0022954 ,
#         1.00000004],
#        [2.        , 2.        , 2.        , ..., 4.50134384, 1.00757418,
#         1.00000012],
#        [2.        , 2.        , 2.        , ..., 4.83862133, 1.06432717,
#         1.00000055]])

# %% [markdown]
# ### AV-MV

# %%
test = mannwhitneyu(av, mv,
                    use_continuity=False, alternative = 'two-sided')
stats = pd.DataFrame(test[0])
p = pd.DataFrame(test[1])

# %%
p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_4635f_row0_col15 {
#   background: pink;
# }
# </style>
# <table id="T_4635f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4635f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4635f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4635f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_4635f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_4635f_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_4635f_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_4635f_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_4635f_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_4635f_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_4635f_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_4635f_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_4635f_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_4635f_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_4635f_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_4635f_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_4635f_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_4635f_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_4635f_level0_col17" class="col_heading level0 col17" >17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4635f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4635f_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_4635f_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_4635f_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_4635f_row0_col3" class="data row0 col3" >0.084054</td>
#       <td id="T_4635f_row0_col4" class="data row0 col4" >0.090407</td>
#       <td id="T_4635f_row0_col5" class="data row0 col5" >0.129059</td>
#       <td id="T_4635f_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_4635f_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_4635f_row0_col8" class="data row0 col8" >0.113627</td>
#       <td id="T_4635f_row0_col9" class="data row0 col9" >0.888277</td>
#       <td id="T_4635f_row0_col10" class="data row0 col10" >0.126053</td>
#       <td id="T_4635f_row0_col11" class="data row0 col11" >0.957997</td>
#       <td id="T_4635f_row0_col12" class="data row0 col12" >0.170429</td>
#       <td id="T_4635f_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_4635f_row0_col14" class="data row0 col14" >0.168881</td>
#       <td id="T_4635f_row0_col15" class="data row0 col15" >0.025243</td>
#       <td id="T_4635f_row0_col16" class="data row0 col16" >0.085939</td>
#       <td id="T_4635f_row0_col17" class="data row0 col17" >0.315266</td>
#     </tr>
#   </tbody>
# </table>

# %%
av_mv = p[(p < 0.05).any(axis=1)].index
av_mv
# Out:
# Int64Index([15], dtype='int64')

# %% [markdown]
# ### AV-PV

# %%
test = mannwhitneyu(av, pv, use_continuity=False, alternative = 'two-sided')
stats = pd.DataFrame(test[0])
p = pd.DataFrame(test[1])

av_pv = p[(p < 0.05).any(axis=1)].index

print(av_pv)
# Out:
# Int64Index([3, 4, 5, 8, 10, 12, 14, 15, 16, 17], dtype='int64')

# %%
p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_83e2f_row0_col3, #T_83e2f_row0_col4, #T_83e2f_row0_col5, #T_83e2f_row0_col8, #T_83e2f_row0_col10, #T_83e2f_row0_col12, #T_83e2f_row0_col14, #T_83e2f_row0_col15, #T_83e2f_row0_col16, #T_83e2f_row0_col17 {
#   background: pink;
# }
# </style>
# <table id="T_83e2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83e2f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_83e2f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_83e2f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_83e2f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_83e2f_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_83e2f_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_83e2f_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_83e2f_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_83e2f_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_83e2f_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_83e2f_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_83e2f_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_83e2f_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_83e2f_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_83e2f_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_83e2f_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_83e2f_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_83e2f_level0_col17" class="col_heading level0 col17" >17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83e2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83e2f_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_83e2f_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_83e2f_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_83e2f_row0_col3" class="data row0 col3" >0.000389</td>
#       <td id="T_83e2f_row0_col4" class="data row0 col4" >0.001512</td>
#       <td id="T_83e2f_row0_col5" class="data row0 col5" >0.001453</td>
#       <td id="T_83e2f_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_83e2f_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_83e2f_row0_col8" class="data row0 col8" >0.018592</td>
#       <td id="T_83e2f_row0_col9" class="data row0 col9" >0.582428</td>
#       <td id="T_83e2f_row0_col10" class="data row0 col10" >0.001324</td>
#       <td id="T_83e2f_row0_col11" class="data row0 col11" >0.132039</td>
#       <td id="T_83e2f_row0_col12" class="data row0 col12" >0.000002</td>
#       <td id="T_83e2f_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_83e2f_row0_col14" class="data row0 col14" >0.018199</td>
#       <td id="T_83e2f_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_83e2f_row0_col16" class="data row0 col16" >0.000509</td>
#       <td id="T_83e2f_row0_col17" class="data row0 col17" >0.002806</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### AV-TV

# %%
test = mannwhitneyu(av, tv, use_continuity=False, alternative = 'two-sided')
stats = pd.DataFrame(test[0])
p = pd.DataFrame(test[1])

p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)

av_tv = p[(p < 0.05).any(axis=1)].index

print(av_tv)
# Out:
# Int64Index([3, 4, 5, 8, 9, 10, 11, 12, 14, 15, 16], dtype='int64')

# %%
p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_88a76_row0_col3, #T_88a76_row0_col4, #T_88a76_row0_col5, #T_88a76_row0_col8, #T_88a76_row0_col9, #T_88a76_row0_col10, #T_88a76_row0_col11, #T_88a76_row0_col12, #T_88a76_row0_col14, #T_88a76_row0_col15, #T_88a76_row0_col16 {
#   background: pink;
# }
# </style>
# <table id="T_88a76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88a76_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_88a76_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_88a76_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_88a76_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_88a76_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_88a76_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_88a76_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_88a76_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_88a76_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_88a76_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_88a76_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_88a76_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_88a76_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_88a76_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_88a76_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_88a76_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_88a76_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_88a76_level0_col17" class="col_heading level0 col17" >17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88a76_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_88a76_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_88a76_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_88a76_row0_col3" class="data row0 col3" >0.000001</td>
#       <td id="T_88a76_row0_col4" class="data row0 col4" >0.000018</td>
#       <td id="T_88a76_row0_col5" class="data row0 col5" >0.000005</td>
#       <td id="T_88a76_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_88a76_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_88a76_row0_col8" class="data row0 col8" >0.001113</td>
#       <td id="T_88a76_row0_col9" class="data row0 col9" >0.000018</td>
#       <td id="T_88a76_row0_col10" class="data row0 col10" >0.000004</td>
#       <td id="T_88a76_row0_col11" class="data row0 col11" >0.000070</td>
#       <td id="T_88a76_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_88a76_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_88a76_row0_col14" class="data row0 col14" >0.000464</td>
#       <td id="T_88a76_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_88a76_row0_col16" class="data row0 col16" >0.000001</td>
#       <td id="T_88a76_row0_col17" class="data row0 col17" >0.408226</td>
#     </tr>
#   </tbody>
# </table>

# %%
list(set(av_mv) & set(av_pv) & set(av_tv) )
# Out:
# [15]

# %% [markdown]
# ### MV-PV

# %%
test = mannwhitneyu(mv, pv, use_continuity=False, alternative = 'two-sided')
stats = pd.DataFrame(test[0])
p = pd.DataFrame(test[1])


mv_pv = p[(p < 0.05).any(axis=1)].index

print(mv_pv)
# Out:
# Int64Index([3, 4, 5, 8, 10, 12, 14, 15, 16, 17], dtype='int64')

# %%
p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_b3090_row0_col3, #T_b3090_row0_col4, #T_b3090_row0_col5, #T_b3090_row0_col8, #T_b3090_row0_col10, #T_b3090_row0_col12, #T_b3090_row0_col14, #T_b3090_row0_col15, #T_b3090_row0_col16, #T_b3090_row0_col17 {
#   background: pink;
# }
# </style>
# <table id="T_b3090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3090_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b3090_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b3090_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b3090_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b3090_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_b3090_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_b3090_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_b3090_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_b3090_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_b3090_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_b3090_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_b3090_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_b3090_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_b3090_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_b3090_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_b3090_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_b3090_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_b3090_level0_col17" class="col_heading level0 col17" >17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3090_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3090_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_b3090_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_b3090_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b3090_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_b3090_row0_col4" class="data row0 col4" >0.000001</td>
#       <td id="T_b3090_row0_col5" class="data row0 col5" >0.000005</td>
#       <td id="T_b3090_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_b3090_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_b3090_row0_col8" class="data row0 col8" >0.000154</td>
#       <td id="T_b3090_row0_col9" class="data row0 col9" >0.474726</td>
#       <td id="T_b3090_row0_col10" class="data row0 col10" >0.000004</td>
#       <td id="T_b3090_row0_col11" class="data row0 col11" >0.161503</td>
#       <td id="T_b3090_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_b3090_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_b3090_row0_col14" class="data row0 col14" >0.000397</td>
#       <td id="T_b3090_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_b3090_row0_col16" class="data row0 col16" >0.000001</td>
#       <td id="T_b3090_row0_col17" class="data row0 col17" >0.000097</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### MV_TV

# %%
test = mannwhitneyu(mv, tv, use_continuity=False, alternative = 'two-sided')
stats = pd.DataFrame(test[0])
p = pd.DataFrame(test[1])

mv_tv = p[(p < 0.05).any(axis=1)].index

print(mv_tv)
# Out:
# Int64Index([3, 4, 5, 8, 9, 10, 11, 12, 14, 15, 16], dtype='int64')

# %%
p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_2e82c_row0_col3, #T_2e82c_row0_col4, #T_2e82c_row0_col5, #T_2e82c_row0_col8, #T_2e82c_row0_col9, #T_2e82c_row0_col10, #T_2e82c_row0_col11, #T_2e82c_row0_col12, #T_2e82c_row0_col14, #T_2e82c_row0_col15, #T_2e82c_row0_col16 {
#   background: pink;
# }
# </style>
# <table id="T_2e82c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e82c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2e82c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2e82c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2e82c_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2e82c_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_2e82c_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_2e82c_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_2e82c_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_2e82c_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_2e82c_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_2e82c_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_2e82c_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_2e82c_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_2e82c_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_2e82c_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_2e82c_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_2e82c_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_2e82c_level0_col17" class="col_heading level0 col17" >17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e82c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e82c_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_2e82c_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_2e82c_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_2e82c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_2e82c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_2e82c_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_2e82c_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_2e82c_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_2e82c_row0_col8" class="data row0 col8" >0.000004</td>
#       <td id="T_2e82c_row0_col9" class="data row0 col9" >0.000010</td>
#       <td id="T_2e82c_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_2e82c_row0_col11" class="data row0 col11" >0.000148</td>
#       <td id="T_2e82c_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_2e82c_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_2e82c_row0_col14" class="data row0 col14" >0.000003</td>
#       <td id="T_2e82c_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_2e82c_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_2e82c_row0_col17" class="data row0 col17" >0.105924</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### PV-TV

# %%
test = mannwhitneyu(pv, tv, use_continuity=False, alternative = 'two-sided')
stats = pd.DataFrame(test[0])
p = pd.DataFrame(test[1])

pv_tv = p[(p < 0.05).any(axis=1)].index

print(pv_tv)
# Out:
# Int64Index([9, 11, 12, 14], dtype='int64')

# %%
p.T.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_f054d_row0_col9, #T_f054d_row0_col11, #T_f054d_row0_col12, #T_f054d_row0_col14 {
#   background: pink;
# }
# </style>
# <table id="T_f054d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f054d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f054d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f054d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f054d_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f054d_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_f054d_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_f054d_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_f054d_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_f054d_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_f054d_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_f054d_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_f054d_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_f054d_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_f054d_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_f054d_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_f054d_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_f054d_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_f054d_level0_col17" class="col_heading level0 col17" >17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f054d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f054d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_f054d_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_f054d_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_f054d_row0_col3" class="data row0 col3" >0.066574</td>
#       <td id="T_f054d_row0_col4" class="data row0 col4" >0.162575</td>
#       <td id="T_f054d_row0_col5" class="data row0 col5" >0.056678</td>
#       <td id="T_f054d_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_f054d_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_f054d_row0_col8" class="data row0 col8" >0.135997</td>
#       <td id="T_f054d_row0_col9" class="data row0 col9" >0.000258</td>
#       <td id="T_f054d_row0_col10" class="data row0 col10" >0.050811</td>
#       <td id="T_f054d_row0_col11" class="data row0 col11" >0.023512</td>
#       <td id="T_f054d_row0_col12" class="data row0 col12" >0.005199</td>
#       <td id="T_f054d_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_f054d_row0_col14" class="data row0 col14" >0.044701</td>
#       <td id="T_f054d_row0_col15" class="data row0 col15" >0.917943</td>
#       <td id="T_f054d_row0_col16" class="data row0 col16" >0.060866</td>
#       <td id="T_f054d_row0_col17" class="data row0 col17" >0.065624</td>
#     </tr>
#   </tbody>
# </table>

# %%
columns = ["min_diagonal_line_length", "min_vertical_line_length", "min_white_vertical_line_length",
           "recurrence_rate","determinism","average_diagonal_line","longest_diagonal_line","divergence",
           "entropy_diagonal_lines", "laminarity", "trapping_time", "longest_vertical_line", 
           "entropy_vertical_lines", "average_white_vertical_line", "longest_white_vertical_line", 
           "entropy_white_vertical_lines", "ratio_determinism_recurrence_rate", "ratio_laminarity_determinism "]

# %%
df_av = pd.DataFrame(av, columns =columns )
df_mv = pd.DataFrame(mv, columns =columns )
df_pv = pd.DataFrame(pv, columns =columns )
df_tv = pd.DataFrame(tv, columns =columns )

# %%
df = pd.concat([df_av, df_mv, df_pv, df_tv], axis =0)
df.head()
# Out:
#    min_diagonal_line_length  min_vertical_line_length  \
# 0                       2.0                       2.0
# 1                       2.0                       2.0
# 2                       2.0                       2.0
# 3                       2.0                       2.0
# 4                       2.0                       2.0
#
#    min_white_vertical_line_length  recurrence_rate  determinism  \
# 0                             2.0         0.992689          1.0
# 1                             2.0         1.000000          1.0
# 2                             2.0         1.000000          1.0
# 3                             2.0         1.000000          1.0
# 4                             2.0         1.000000          1.0
#
#    average_diagonal_line  longest_diagonal_line  divergence  \
# 0            1119.932797                39997.0    0.000025
# 1           19999.500750                39997.0    0.000025
# 2           19999.500750                39997.0    0.000025
# 3           19999.500750                39997.0    0.000025
# 4           19999.500750                39997.0    0.000025
#
#    entropy_diagonal_lines  laminarity  trapping_time  longest_vertical_line  \
# 0                4.925425         1.0     2110.97942                25686.0
# 1               10.596535         1.0    39997.99990                39998.0
# 2               10.596535         1.0    39997.99990                39998.0
# 3               10.596535         1.0    39997.99990                39998.0
# 4               10.596535         1.0    39997.99990                39998.0
#
#    entropy_vertical_lines  average_white_vertical_line  \
# 0                4.039169                    16.757784
# 1                0.000000                          NaN
# 2                0.000000                          NaN
# 3                0.000000                          NaN
# 4                0.000000                          NaN
#
#    longest_white_vertical_line  entropy_white_vertical_lines  \
# 0                      25786.0                      2.846613
# 1                          0.0                      0.000000
# 2                          0.0                      0.000000
# 3                          0.0                      0.000000
# 4                          0.0                      0.000000
#
#    ratio_determinism_recurrence_rate  ratio_laminarity_determinism
# 0                           1.007365                            1.0
# 1                           1.000000                            1.0
# 2                           1.000000                            1.0
# 3                           1.000000                            1.0
# 4                           1.000000                            1.0

# %%
df
# Out:
#       min_diagonal_line_length  min_vertical_line_length  \
# 0                          2.0                       2.0
# 1                          2.0                       2.0
# 2                          2.0                       2.0
# 3                          2.0                       2.0
# 4                          2.0                       2.0
# ...                        ...                       ...
# 1200                       2.0                       2.0
# 1201                       2.0                       2.0
# 1202                       2.0                       2.0
# 1203                       2.0                       2.0
# 1204                       2.0                       2.0
#
#       min_white_vertical_line_length  recurrence_rate  determinism  \
# 0                                2.0         0.992689     1.000000
# 1                                2.0         1.000000     1.000000
# 2                                2.0         1.000000     1.000000
# 3                                2.0         1.000000     1.000000
# 4                                2.0         1.000000     1.000000
# ...                              ...              ...          ...
# 1200                             2.0         0.862485     0.999998
# 1201                             2.0         0.906680     0.999999
# 1202                             2.0         0.879299     0.999999
# 1203                             2.0         0.908215     0.999996
# 1204                             2.0         0.919544     0.999998
#
#       average_diagonal_line  longest_diagonal_line  divergence  \
# 0               1119.932797                39997.0    0.000025
# 1              19999.500750                39997.0    0.000025
# 2              19999.500750                39997.0    0.000025
# 3              19999.500750                39997.0    0.000025
# 4              19999.500750                39997.0    0.000025
# ...                     ...                    ...         ...
# 1200             339.212861                39997.0    0.000025
# 1201             502.727399                39997.0    0.000025
# 1202             408.889079                39997.0    0.000025
# 1203             456.379323                39997.0    0.000025
# 1204             500.982782                39997.0    0.000025
#
#       entropy_diagonal_lines  laminarity  trapping_time  \
# 0                   4.925425    1.000000    2110.979420
# 1                  10.596535    1.000000   39997.999900
# 2                  10.596535    1.000000   39997.999900
# 3                  10.596535    1.000000   39997.999900
# 4                  10.596535    1.000000   39997.999900
# ...                      ...         ...            ...
# 1200                6.417371    0.999999     527.995004
# 1201                6.770139    0.999999     776.040309
# 1202                6.633837    0.999998     626.696060
# 1203                6.709152    0.999997     693.866745
# 1204                6.870929    0.999998     788.208003
#
#       longest_vertical_line  entropy_vertical_lines  \
# 0                   25686.0                4.039169
# 1                   39998.0                0.000000
# 2                   39998.0                0.000000
# 3                   39998.0                0.000000
# 4                   39998.0                0.000000
# ...                     ...                     ...
# 1200                 8235.0                6.435529
# 1201                 9165.0                6.510257
# 1202                 9620.0                6.566982
# 1203                10559.0                6.590558
# 1204                 9679.0                6.728481
#
#       average_white_vertical_line  longest_white_vertical_line  \
# 0                       16.757784                      25786.0
# 1                             NaN                          0.0
# 2                             NaN                          0.0
# 3                             NaN                          0.0
# 4                             NaN                          0.0
# ...                           ...                          ...
# 1200                    85.372912                       9471.0
# 1201                    81.542455                       9454.0
# 1202                    87.096694                      10946.0
# 1203                    71.089426                      14238.0
# 1204                    70.557061                      13639.0
#
#       entropy_white_vertical_lines  ratio_determinism_recurrence_rate  \
# 0                         2.846613                           1.007365
# 1                         0.000000                           1.000000
# 2                         0.000000                           1.000000
# 3                         0.000000                           1.000000
# 4                         0.000000                           1.000000
# ...                            ...                                ...
# 1200                      5.204538                           1.159438
# 1201                      5.166928                           1.102924
# 1202                      5.243345                           1.137268
# 1203                      5.081825                           1.101056
# 1204                      5.078580                           1.087493
#
#       ratio_laminarity_determinism
# 0                          1.000000
# 1                          1.000000
# 2                          1.000000
# 3                          1.000000
# 4                          1.000000
# ...                             ...
# 1200                       1.000000
# 1201                       1.000000
# 1202                       1.000000
# 1203                       1.000000
# 1204                       1.000001
#
# [4728 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# min_diagonal_line_length                0
# min_vertical_line_length                0
# min_white_vertical_line_length          0
# recurrence_rate                         0
# determinism                             0
# average_diagonal_line                   0
# longest_diagonal_line                   0
# divergence                              0
# entropy_diagonal_lines                  0
# laminarity                              0
# trapping_time                           0
# longest_vertical_line                   0
# entropy_vertical_lines                  0
# average_white_vertical_line          1543
# longest_white_vertical_line             0
# entropy_white_vertical_lines            0
# ratio_determinism_recurrence_rate       0
# ratio_laminarity_determinism            0
# dtype: int64

# %%
#df.to_csv("/Users/ecem/Desktop/phonocardiogram/data/rqa.csv")

# %%
df.columns.shape
# Out:
# (18,)

# %%
'min_diagonal_line_length', 
'min_vertical_line_length',
       'min_white_vertical_line_length', 
    'recurrence_rate', 'determinism',
       'average_diagonal_line', 
        'longest_diagonal_line', 
        'divergence',
       'entropy_diagonal_lines',
    'laminarity',
    'trapping_time',
       'longest_vertical_line', 
        'entropy_vertical_lines',
       'longest_white_vertical_line',
       'entropy_white_vertical_lines',
        'ratio_determinism_recurrence_rate',
       'ratio_laminarity_determinism '
